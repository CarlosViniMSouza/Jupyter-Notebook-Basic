# %% [markdown]
# ### Python para Ciência de Dados (Sessão 1)

# %%
## Importação das bibliotecas
import pandas as pd ##Para a manipulação de DataFrames
import numpy as np ## Cálculo algébricos
import matplotlib.pyplot as plt ##Visualização dos dados

# %%
# Criando um DataFrame do zero com um dicionário do Python

norte_brasil_1 = {'Siglas': ('AC','AP','AM','PA','RO','RR','TO'),'Estados': ('Acre','Amapá',
'Amazonas','Pará','Rondônia','Roraima','Tocantins'),
'Capitais': ('Rio Branco','Macapá','Manaus','Belém','Porto Velho','Boa Vista','Palmas')}
df1 = pd.DataFrame(norte_brasil_1)

# %%
df1
# Out:
#   Siglas    Estados     Capitais
# 0     AC       Acre   Rio Branco
# 1     AP      Amapá       Macapá
# 2     AM   Amazonas       Manaus
# 3     PA       Pará        Belém
# 4     RO   Rondônia  Porto Velho
# 5     RR    Roraima    Boa Vista
# 6     TO  Tocantins       Palmas

# %%
norte_brasil_2_0 = {'Siglas': ('AC','AP','AM','PA','RO','RR','TO'),'Estados': ('Acre','Amapá',
'Amazonas','Pará','Rondônia','Roraima','Tocantins'),
'Capitais': ('Rio Branco','Macapá','Manaus','Belém','Porto Velho','Boa Vista','Palmas')}
df2_0 = pd.DataFrame(norte_brasil_2_0)

# %%
df2_0
# Out:
#   Siglas    Estados     Capitais
# 0     AC       Acre   Rio Branco
# 1     AP      Amapá       Macapá
# 2     AM   Amazonas       Manaus
# 3     PA       Pará        Belém
# 4     RO   Rondônia  Porto Velho
# 5     RR    Roraima    Boa Vista
# 6     TO  Tocantins       Palmas

# %%
norte_brasil_2 = {'Siglas': ('AC','AP','AM','PA','RO','RR','TO'),'Areas':(164123.040, 142828.521, 1559146.876, 1247954.666, 237590.547, 224300.506,
277720.520),'População':(869265, 829494, 4080611, 8513497, 1757589, 576568,1555229)}
df2 = pd.DataFrame(norte_brasil_2)

# %%
df2
# Out:
#   Siglas        Areas  População
# 0     AC   164123.040     869265
# 1     AP   142828.521     829494
# 2     AM  1559146.876    4080611
# 3     PA  1247954.666    8513497
# 4     RO   237590.547    1757589
# 5     RR   224300.506     576568
# 6     TO   277720.520    1555229

# %%
# Juntando dois dataframes
norte_brasil = pd.merge(df1,df2)
norte_brasil
# Out:
#   Siglas    Estados     Capitais        Areas  População
# 0     AC       Acre   Rio Branco   164123.040     869265
# 1     AP      Amapá       Macapá   142828.521     829494
# 2     AM   Amazonas       Manaus  1559146.876    4080611
# 3     PA       Pará        Belém  1247954.666    8513497
# 4     RO   Rondônia  Porto Velho   237590.547    1757589
# 5     RR    Roraima    Boa Vista   224300.506     576568
# 6     TO  Tocantins       Palmas   277720.520    1555229

# %%
cod_bancos=pd.read_html('https://www.codigobanco.com')

# %%
cod_bancos
# Out:
# [    Código                                              Banco  \
#  0      654                              Banco A.J.Renner S.A.
#  1      246                              Banco ABC Brasil S.A.
#  2      025                                    Banco Alfa S.A.
#  3      641                                Banco Alvorada S.A.
#  4      213                                    Banco Arbi S.A.
#  5      019                        Banco Azteca do Brasil S.A.
#  6      029                                  Banco Banerj S.A.
#  7      000                                 Banco Bankpar S.A.
#  8      740                                Banco Barclays S.A.
#  9      107                                     Banco BBM S.A.
#  10     031                                     Banco Beg S.A.
#  11     739                                     Banco BGN S.A.
#  12     096  Banco BM&F de Serviços de Liquidação e Custódi...
#  13     318                                     Banco BMG S.A.
# ...

# %%
cod_bancos = cod_bancos[0]

# %%
cod_bancos
# Out:
#     Código                                              Banco  \
# 0      654                              Banco A.J.Renner S.A.
# 1      246                              Banco ABC Brasil S.A.
# 2      025                                    Banco Alfa S.A.
# 3      641                                Banco Alvorada S.A.
# 4      213                                    Banco Arbi S.A.
# 5      019                        Banco Azteca do Brasil S.A.
# 6      029                                  Banco Banerj S.A.
# 7      000                                 Banco Bankpar S.A.
# 8      740                                Banco Barclays S.A.
# 9      107                                     Banco BBM S.A.
# 10     031                                     Banco Beg S.A.
# 11     739                                     Banco BGN S.A.
# 12     096  Banco BM&F de Serviços de Liquidação e Custódi...
# 13     318                                     Banco BMG S.A.
# ...

# %%
cod_bancos.head(10)
# Out:
#   Código                        Banco                  Site
# 0    654        Banco A.J.Renner S.A.                     -
# 1    246        Banco ABC Brasil S.A.  www.abcbrasil.com.br
# 2    025              Banco Alfa S.A.  www.bancoalfa.com.br
# 3    641          Banco Alvorada S.A.                     -
# 4    213              Banco Arbi S.A.       www.arbi.com.br
# 5    019  Banco Azteca do Brasil S.A.                     -
# 6    029            Banco Banerj S.A.     www.banerj.com.br
# 7    000           Banco Bankpar S.A.          www.aexp.com
# 8    740          Banco Barclays S.A.      www.barclays.com
# 9    107               Banco BBM S.A.    www.bbmbank.com.br

# %%
cod_bancos.tail(10)
# Out:
#     Código                                           Banco  \
# 160    079                                  JBS Banco S.A.
# 161    488                             JPMorgan Chase Bank
# 162    014              Natixis Brasil S.A. Banco Múltiplo
# 163    753           NBC Bank Brasil S.A. - Banco Múltiplo
# 164  086-8  OBOE Crédito Financiamento e Investimento S.A.
# 165    254                               Paraná Banco S.A.
# 166    409     UNIBANCO - União de Bancos Brasileiros S.A.
# 167    230                     Unicard Banco Múltiplo S.A.
# 168  091-4            Unicred Central do Rio Grande do Sul
# 169    084                         Unicred Norte do Paraná
#
#                        Site
# 160     www.bancojbs.com.br
# 161   www.jpmorganchase.com
# 162                       -
# 163      www.nbcbank.com.br
# 164                       -
# 165  www.paranabanco.com.br
# 166     www.unibanco.com.br
# 167      www.unicard.com.br
# 168   www.unicred-rs.com.br
# ...

# %%
gas=pd.read_csv('glp.csv', sep=';', encoding='latin1')

# %%
gas
# Out:
#       Região - Sigla Estado - Sigla    Município  \
# 0                 CO             DF     BRASILIA
# 1                 CO             DF     BRASILIA
# 2                 CO             DF     BRASILIA
# 3                 CO             DF     BRASILIA
# 4                 CO             DF     BRASILIA
# 5                 CO             DF     BRASILIA
# 6                 CO             DF     BRASILIA
# 7                 CO             DF     BRASILIA
# 8                 CO             DF     BRASILIA
# 9                 CO             DF     BRASILIA
# 10                CO             DF     BRASILIA
# 11                CO             DF     BRASILIA
# 12                CO             DF     BRASILIA
# 13                CO             DF     BRASILIA
# 14                CO             DF     BRASILIA
# 15                CO             DF     BRASILIA
# 16                CO             DF     BRASILIA
# 17                CO             DF     BRASILIA
# ...

# %%
gas.columns
# Out:
# Index(['Região - Sigla', 'Estado - Sigla', 'Município', 'Revenda',
#        'CNPJ da Revenda', 'Produto', 'Data da Coleta', 'Valor de Venda',
#        'Valor de Compra', 'Unidade de Medida', 'Bandeira'],
#       dtype='object')

# %%
gas.columns = (['Sigla', 'Estado', 'Municipio', 'Revenda',
       'CNPJ', 'Produto', 'Coleta', 'Venda',
       'Compra', 'Medida', 'Bandeira'])

# %%
gas
# Out:
#       Sigla Estado    Municipio  \
# 0        CO     DF     BRASILIA
# 1        CO     DF     BRASILIA
# 2        CO     DF     BRASILIA
# 3        CO     DF     BRASILIA
# 4        CO     DF     BRASILIA
# 5        CO     DF     BRASILIA
# 6        CO     DF     BRASILIA
# 7        CO     DF     BRASILIA
# 8        CO     DF     BRASILIA
# 9        CO     DF     BRASILIA
# 10       CO     DF     BRASILIA
# 11       CO     DF     BRASILIA
# 12       CO     DF     BRASILIA
# 13       CO     DF     BRASILIA
# 14       CO     DF     BRASILIA
# 15       CO     DF     BRASILIA
# 16       CO     DF     BRASILIA
# 17       CO     DF     BRASILIA
# 18       CO     DF     BRASILIA
# 19       CO     DF     BRASILIA
# 20       CO     DF     BRASILIA
# 21       CO     DF     BRASILIA
# 22       CO     DF     BRASILIA
# 23       CO     DF     BRASILIA
# 24       CO     DF     BRASILIA
# 25       CO     DF     BRASILIA
# 26       CO     DF     BRASILIA
# 27       CO     DF     BRASILIA
# ...

# %%
gas.isnull().sum()
# Out:
# Sigla            0
# Estado           0
# Municipio        0
# Revenda          0
# CNPJ             0
# Produto          0
# Coleta           0
# Venda            0
# Compra       11759
# Medida           0
# Bandeira         0
# dtype: int64

# %%
gas_manaus=gas[gas['Municipio']=='MANAUS']

# %%
gas_manaus
# Out:
#      Sigla Estado Municipio  \
# 2004     N     AM    MANAUS
# 2005     N     AM    MANAUS
# 2006     N     AM    MANAUS
# 2007     N     AM    MANAUS
# 2008     N     AM    MANAUS
# 2009     N     AM    MANAUS
# 2010     N     AM    MANAUS
# 2011     N     AM    MANAUS
# 2012     N     AM    MANAUS
# 2013     N     AM    MANAUS
# 2014     N     AM    MANAUS
# 2015     N     AM    MANAUS
# 2016     N     AM    MANAUS
# 2017     N     AM    MANAUS
# 2018     N     AM    MANAUS
# 2019     N     AM    MANAUS
# 2020     N     AM    MANAUS
# 2021     N     AM    MANAUS
# 2022     N     AM    MANAUS
# 2023     N     AM    MANAUS
# 2024     N     AM    MANAUS
# 2025     N     AM    MANAUS
# 2026     N     AM    MANAUS
# 2027     N     AM    MANAUS
# 2028     N     AM    MANAUS
# 2029     N     AM    MANAUS
# 2030     N     AM    MANAUS
# 2031     N     AM    MANAUS
# 2032     N     AM    MANAUS
# 2033     N     AM    MANAUS
# ...    ...    ...       ...
# 2130     N     AM    MANAUS
# ...

# %%
gas_manaus.max()
# Out:
# Sigla                        N
# Estado                      AM
# Municipio               MANAUS
# Revenda      W A DA SILVA NETO
# CNPJ               9,02408E+12
# Produto                    GLP
# Coleta              27/11/2019
# Venda                       84
# Compra                   66.07
# Medida              R$ / 13 kg
# Bandeira                 SABBÁ
# dtype: object

# %%
gas_manaus=gas_manaus.sort_values(by='Venda')

# %%
gas_manaus
# Out:
#      Sigla Estado Municipio  \
# 2108     N     AM    MANAUS
# 2040     N     AM    MANAUS
# 2035     N     AM    MANAUS
# 2020     N     AM    MANAUS
# 2004     N     AM    MANAUS
# 2051     N     AM    MANAUS
# 2014     N     AM    MANAUS
# 2083     N     AM    MANAUS
# 2022     N     AM    MANAUS
# 2105     N     AM    MANAUS
# 2052     N     AM    MANAUS
# 2106     N     AM    MANAUS
# 2157     N     AM    MANAUS
# 2006     N     AM    MANAUS
# 2029     N     AM    MANAUS
# 2028     N     AM    MANAUS
# 2019     N     AM    MANAUS
# 2090     N     AM    MANAUS
# 2024     N     AM    MANAUS
# 2131     N     AM    MANAUS
# 2133     N     AM    MANAUS
# 2094     N     AM    MANAUS
# 2057     N     AM    MANAUS
# 2026     N     AM    MANAUS
# 2049     N     AM    MANAUS
# 2109     N     AM    MANAUS
# 2047     N     AM    MANAUS
# 2110     N     AM    MANAUS
# 2054     N     AM    MANAUS
# 2087     N     AM    MANAUS
# ...    ...    ...       ...
# 2025     N     AM    MANAUS
# ...

# %%
#inciando parte 2 da sessao data marchine

# %% [markdown]
# <img align="center" style="padding-right:10px;" src="https://archive.ics.uci.edu/ml/assets/MLimages/Large53.jpg">

# %% [markdown]
# ### O conjunto de dados de flores IRIS contém os parâmetros físicos de três espécies de flores - Versicolor, Setosa e Virginica.
#
# ### Os parâmetros numéricos que o conjunto de dados contém são: largura Sépala, comprimento Sépala, largura Pétala e comprimento Pétala.
#
# ### Nestes dados, estaremos prevendo as espécies das flores com base nesses parâmetros.

# %% [markdown]
# <img align="center" style="padding-right:10px;" src="https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png">

# %%
# Importando as bibliotecas
#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
# Carregando a base de dados
#
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['comprimento_sepala', 'largura_sepala', 'comprimento_petala', 'largura_petala', 'classe']
iris = pd.read_csv(url, names=names)

# %%
iris
# Out:
#      comprimento_sepala  largura_sepala  comprimento_petala  largura_petala  \
# 0                   5.1             3.5                 1.4             0.2
# 1                   4.9             3.0                 1.4             0.2
# 2                   4.7             3.2                 1.3             0.2
# 3                   4.6             3.1                 1.5             0.2
# 4                   5.0             3.6                 1.4             0.2
# 5                   5.4             3.9                 1.7             0.4
# 6                   4.6             3.4                 1.4             0.3
# 7                   5.0             3.4                 1.5             0.2
# 8                   4.4             2.9                 1.4             0.2
# 9                   4.9             3.1                 1.5             0.1
# 10                  5.4             3.7                 1.5             0.2
# ...

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# comprimento_sepala    150 non-null float64
# largura_sepala        150 non-null float64
# comprimento_petala    150 non-null float64
# largura_petala        150 non-null float64
# classe                150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.describe()
# Out:
#        comprimento_sepala  largura_sepala  comprimento_petala  largura_petala
# count          150.000000      150.000000          150.000000      150.000000
# mean             5.843333        3.054000            3.758667        1.198667
# std              0.828066        0.433594            1.764420        0.763161
# min              4.300000        2.000000            1.000000        0.100000
# 25%              5.100000        2.800000            1.600000        0.300000
# 50%              5.800000        3.000000            4.350000        1.300000
# 75%              6.400000        3.300000            5.100000        1.800000
# max              7.900000        4.400000            6.900000        2.500000

# %%
iris.groupby('classe').size()
# Out:
# classe
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Visualização dos dados

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.gca()
iris.hist(ax=ax)
plt.show()
# Out:
# /home/ocean/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3296: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fig = plt.figure(figsize = (16,8))
ax = fig.gca()
iris.boxplot()
plt.show()

# %%
iris.iloc[:50,:].corr() #setosa
# Out:
#                     comprimento_sepala  largura_sepala  comprimento_petala  \
# comprimento_sepala            1.000000        0.746780            0.263874
# largura_sepala                0.746780        1.000000            0.176695
# comprimento_petala            0.263874        0.176695            1.000000
# largura_petala                0.279092        0.279973            0.306308
#
#                     largura_petala
# comprimento_sepala        0.279092
# largura_sepala            0.279973
# comprimento_petala        0.306308
# largura_petala            1.000000

# %%
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
array = iris.values
X = array[:,0:4]
Y = array[:,4]
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=10)

# %%
array[0:3,0:4]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2]], dtype=object)

# %%
x_train
# Out:
# array([[5.2, 4.1, 1.5, 0.1],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.6, 2.8, 4.9, 2.0],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.2, 2.2, 4.5, 1.5],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.5, 2.4, 3.7, 1.0],
#        [6.0, 2.9, 4.5, 1.5],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.4, 3.4, 1.7, 0.2],
#        [6.4, 3.1, 5.5, 1.8],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [4.9, 2.5, 4.5, 1.7],
#        [5.1, 2.5, 3.0, 1.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.9, 3.1, 5.4, 2.1],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.8, 2.7, 3.9, 1.2],
#        [6.0, 2.7, 5.1, 1.6],
#        [4.4, 3.2, 1.3, 0.2],
#        [6.8, 3.2, 5.9, 2.3],
#        [7.9, 3.8, 6.4, 2.0],
#        [6.5, 3.0, 5.5, 1.8],
#        [7.6, 3.0, 6.6, 2.1],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.6, 3.4, 1.4, 0.3],
# ...

# %%
y_train
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
# ...

# %%
### Vamos aplicar o algoritmo KNN. Treinar o modelo e prever a acurácia com o conjunto de teste

knn = KNeighborsClassifier()    ### knn é o nome do classificador

knn.fit(x_train,y_train)        ### o classificador knn está usando o método fit

predictions = knn.predict(x_test)   ### predicitions é o vetor que contem o resultado obtido pelo classificador

#print(predictions)

print(accuracy_score(y_test, predictions))  ### mostra a acurácia do modelo

# %%
svc = SVC()
svc.fit(x_train,y_train)
predictions = svc.predict(x_test)
print(accuracy_score(y_test, predictions))
# Out:
# 1.0
# /home/ocean/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
teste = np.array([[5, 2.9, 1, 0.2], [5, 2.9, 1, 3.2], [8.3, 3.0, 2.0, 0.5]])

# %%
teste
# Out:
# array([[5. , 2.9, 1. , 0.2],
#        [5. , 2.9, 1. , 3.2],
#        [8.3, 3. , 2. , 0.5]])

# %%
testando = svc.predict(teste)

# %%
testando
# Out:
# array(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor'], dtype=object)
