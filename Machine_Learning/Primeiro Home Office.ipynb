# %% [markdown]
# ## Vamos trabalhar com aquela tabela do Prof. Msc. Felicien

# %%
# Importação das bibliotecas
import pandas as pd #Para a manipulação de DataFrames
import numpy as np # Cálculo algébricos
import matplotlib.pyplot as plt #Visualização dos dados
from sklearn import datasets as sck #mineração de dados

# %%
phf = pd.read_csv('phf0.csv')

# %%
phf
# Out:
#     Registros                       Curso     Genero  Idade Trabalha  \
# 0         161                  Engenharia  Masculino     18      Não
# 1         226                  Engenharia  Masculino     20      Não
# 2          60                  Engenharia   Feminino     26      Sim
# 3         203                  Engenharia  Masculino     19      Não
# 4         258  Licenciatura em Computação  Masculino     17      Não
# ..        ...                         ...        ...    ...      ...
# 75        147                  Engenharia   Feminino     17      Sim
# 76        171                  Engenharia  Masculino     20      Não
# 77        261                  Engenharia   Feminino     17      Não
# 78        173                Meteorologia   Feminino     18      Não
# 79        230                  Engenharia  Masculino     18      Não
#
#        Cursou_EnsinoMedio  Horas_EstudoSemana  Conhecimento_Matematica
# 0          Escola Militar                  36                        4
# 1          Escola Militar                  20                        3
# 2          Escola Técnica                  10                        3
# 3          Escola Técnica                  20                        4
# 4   Escola Pública Normal                  14                        2
# ..                    ...                 ...                      ...
# 75      Escola Particular                  10                        4
# 76  Escola Pública Normal                   2                        2
# 77         Escola Militar                   5                        4
# 78  Escola Pública Normal                   8                        2
# 79      Escola Particular                  15                        4
#
# [80 rows x 8 columns]
